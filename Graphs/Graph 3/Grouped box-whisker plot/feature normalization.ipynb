# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv("C:/Users/Lenovo/Desktop/Features_three demension.csv")

sns.boxplot(data=data,x="Feature name",y="Feature Value",hue="type")
# Out:
# <AxesSubplot:xlabel='Feature name', ylabel='Feature Value'>

# %%
# normalization
# https://www.delftstack.com/zh/howto/python-pandas/pandas-normalize/
def minmax_norm(df):
    return (df - df.min()) / ( df.max() - df.min())
def mean_norm(df_input):
    return df_input.apply(lambda x: (x-x.mean())/ x.std(), axis=0)

def index_extraction(df):
    a = df["Feature name"].value_counts()
    b = a.index
    return b

Features_name = index_extraction(data)

def data_processing(data,Features_name):
    data_new = pd.DataFrame()
    for i in Features_name:
        mean = data.loc[(data["type"]=="PD")&(data["Feature name"]==i)].mean()
        max = data.loc[(data["type"]=="PD")&(data["Feature name"]==i)].max(numeric_only=True)
        min = data.loc[(data["type"]=="PD")&(data["Feature name"]==i)].min(numeric_only=True)

        a = data.loc[(data["type"]=="PD")&(data["Feature name"]==i)].apply(lambda x: (x-min)/(max-min))
        data_new = pd.concat([data_new,a],axis=0)
    for i in Features_name:
        mean = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].mean()
        max = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].max(numeric_only=True)
        min = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].min(numeric_only=True)

        a = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].apply(lambda x: (x-min)/(max-min))
        data_new = pd.concat([data_new,a],axis=0)
    return data_new
a = data_processing(data,Features_name=Features_name)
a
data
# Out:
#      Feature Value Feature name type
# 0              NaN          NaN  NaN
# 1              NaN          NaN  NaN
# 2              NaN          NaN  NaN
# 3              NaN          NaN  NaN
# 4              NaN          NaN  NaN
# ..             ...          ...  ...
# 373            NaN          NaN  NaN
# 374            NaN          NaN  NaN
# 375            NaN          NaN  NaN
# 376            NaN          NaN  NaN
# 377            NaN          NaN  NaN
#
# [378 rows x 3 columns]

# %%
i="spike_width"

mean = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].mean()
max = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].max(numeric_only=True)
min = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].min(numeric_only=True)

data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].apply(lambda x: (x-min)/(max-min))
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11596\3462235275.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = data.loc[(data["type"]=="Intact")&(data["Feature name"]==i)].mean()
#                Feature Value Feature name type
# 168                      NaN          NaN  NaN
# 169                      NaN          NaN  NaN
# 170                      NaN          NaN  NaN
# 171                      NaN          NaN  NaN
# 172                      NaN          NaN  NaN
# 173                      NaN          NaN  NaN
# 174                      NaN          NaN  NaN
# 175                      NaN          NaN  NaN
# 176                      NaN          NaN  NaN
# 177                      NaN          NaN  NaN
# 178                      NaN          NaN  NaN
# 179                      NaN          NaN  NaN
# ...

# %%
data.loc[(data["type"]=="PD")&(data["Feature name"]=="spike_width")]
# Out:
#     Feature Value Feature name type
# 0        0.000157  spike_width   PD
# 1        0.000172  spike_width   PD
# 2        0.000193  spike_width   PD
# 3        0.000231  spike_width   PD
# 4        0.000233  spike_width   PD
# 5        0.000228  spike_width   PD
# 6        0.000239  spike_width   PD
# 7        0.000231  spike_width   PD
# 8        0.000229  spike_width   PD
# 9        0.000254  spike_width   PD
# 10       0.000238  spike_width   PD
# 11       0.000244  spike_width   PD
# 12       0.000086  spike_width   PD
# 13       0.000090  spike_width   PD
# 14       0.000091  spike_width   PD
# 15       0.000084  spike_width   PD
# 16       0.000092  spike_width   PD
# 17       0.000093  spike_width   PD
# 18       0.000099  spike_width   PD
# 19       0.000100  spike_width   PD
# 20       0.000101  spike_width   PD
# 21       0.000098  spike_width   PD
# 22       0.000098  spike_width   PD
# 23       0.000103  spike_width   PD

# %%
data.head()
# Out:
#    Feature Value Feature name type
# 0       0.000157  spike_width   PD
# 1       0.000172  spike_width   PD
# 2       0.000193  spike_width   PD
# 3       0.000231  spike_width   PD
# 4       0.000233  spike_width   PD

# %%
# create grouped boxplot
sns.boxplot(x = data['day'],
			y = data['total_bill'],
			hue = data['sex'])
